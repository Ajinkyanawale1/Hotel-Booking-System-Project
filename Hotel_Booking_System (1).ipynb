# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/hotel_bookings 2.csv')

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.columns.values
# Out:
# array(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'], dtype=object)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
type(df['reservation_status_date'])
# Out:
# pandas.core.series.Series

# %%
df['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
df['deposit_type'].unique()
# Out:
# array(['No Deposit', 'Refundable', 'Non Refund'], dtype=object)

# %%
df.loc[ :20 ,'children':'booking_changes' ]
# Out:
#     children  babies meal country market_segment distribution_channel  \
# 0        0.0       0   BB     PRT         Direct               Direct
# 1        0.0       0   BB     PRT         Direct               Direct
# 2        0.0       0   BB     GBR         Direct               Direct
# 3        0.0       0   BB     GBR      Corporate            Corporate
# 4        0.0       0   BB     GBR      Online TA                TA/TO
# 5        0.0       0   BB     GBR      Online TA                TA/TO
# 6        0.0       0   BB     PRT         Direct               Direct
# 7        0.0       0   FB     PRT         Direct               Direct
# 8        0.0       0   BB     PRT      Online TA                TA/TO
# 9        0.0       0   HB     PRT  Offline TA/TO                TA/TO
# 10       0.0       0   BB     PRT      Online TA                TA/TO
# 11       0.0       0   HB     PRT      Online TA                TA/TO
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['reservation_status_date'].unique()
# Out:
# array(['1/7/2015', '2/7/2015', '3/7/2015', '6/5/2015', '22/4/2015',
#        '23/6/2015', '5/7/2015', '6/7/2015', '7/7/2015', '8/7/2015',
#        '11/5/2015', '15/7/2015', '16/7/2015', '29/5/2015', '19/5/2015',
#        '19/6/2015', '23/5/2015', '18/5/2015', '9/7/2015', '2/6/2015',
#        '13/7/2015', '4/7/2015', '29/6/2015', '16/6/2015', '18/6/2015',
#        '12/6/2015', '9/6/2015', '26/5/2015', '11/7/2015', '12/7/2015',
#        '17/7/2015', '15/4/2015', '13/5/2015', '10/7/2015', '20/5/2015',
#        '12/5/2015', '14/7/2015', '17/6/2015', '1/5/2015', '30/3/2015',
#        '19/7/2015', '3/6/2015', '26/6/2015', '14/5/2015', '20/7/2015',
#        '7/5/2015', '28/5/2015', '13/4/2015', '25/3/2015', '21/7/2015',
#        '27/6/2015', '18/7/2015', '23/7/2015', '8/6/2015', '22/6/2015',
#        '24/6/2015', '5/3/2015', '1/6/2015', '24/4/2015', '22/7/2015',
#        '27/5/2015', '6/4/2015', '11/4/2015', '25/7/2015', '28/7/2015',
# ...

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'],format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['agent'],axis=1,inplace=True)

# %%
df.drop(['company'],axis=1,inplace=True)

# %%
df['country'] = df['country'].ffill()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.482918     106.863097           0.707476
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
len(df['adr'].unique())
# Out:
# 8879

# %%
df['adr'].value_counts()
# Out:
# adr
# 62.00     3754
# 75.00     2715
# 90.00     2473
# 65.00     2418
# 0.00      1959
#           ...
# 89.43        1
# 63.07        1
# 55.69        1
# 49.51        1
# 157.71       1
# Name: count, Length: 8879, dtype: int64

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Visualization

# %%
df['hotel'].value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
df['is_canceled'].value_counts()
# Out:
# is_canceled
# 0    75166
# 1    44224
# Name: count, dtype: int64

# %%
sns.countplot(x='is_canceled',data=df)
# Out:
# <Axes: xlabel='is_canceled', ylabel='count'>

# %%
sns.countplot(x='hotel',data=df)
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %%
sns.countplot(x='hotel',hue='is_canceled',data=df,palette='Blues')
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %%
+'
# Out:
# <Axes: xlabel='is_canceled', ylabel='count'>

# %%
plt.figure(figsize=(15,15))
a = df.select_dtypes(include=[int, float])
sns.heatmap(a.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='reservation_status_date',y='adr',hue='hotel',data=df)
# Out:
# <Axes: xlabel='reservation_status_date', ylabel='adr'>

# %%
sns.barplot(x='hotel',y='adr',data=df)
# Out:
# <Axes: xlabel='hotel', ylabel='adr'>

# %%
ax = sns.barplot(x='hotel',y='adr',hue='is_canceled',data=df)
for container in ax.containers:
    ax.bar_label(container)

# %%
sns.barplot(x='hotel',y='adr',hue='is_repeated_guest',data=df)
# Out:
# <Axes: xlabel='hotel', ylabel='adr'>

# %%
sns.barplot(x='is_canceled',y='adr',hue='is_repeated_guest',data=df)
# Out:
# <Axes: xlabel='is_canceled', ylabel='adr'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x='arrival_date_month',y='adr',data=df)
for container in ax.containers:
    ax.bar_label(container)

# %%
plt.figure(figsize=(14,8))
ax = sns.barplot(x='arrival_date_month',y='adr',hue='is_canceled',data=df)
for container in ax.containers:
    ax.bar_label(container)

# %%
plt.figure(figsize=(14,8))
ax = sns.barplot(x='arrival_date_month',y='adr',hue='is_repeated_guest',data=df)
for container in ax.containers:
    ax.bar_label(container)

# %%
plt.figure(figsize=(14,8))
sns.barplot(x='arrival_date_year',y='adr',data=df[df['is_canceled']==1].groupby('arrival_date_year')['adr'].sum().reset_index())
# Out:
# <Axes: xlabel='arrival_date_year', ylabel='adr'>

# %%
b = df[df['is_canceled']==1]
county = b['country'].value_counts().head(10)
#county
plt.figure(figsize=(10,10))
plt.pie(county,labels=county ,autopct='%2.1f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x78628fd44640>,
# ...
#  [Text(-0.8884446706903009, -0.6485877482052858, '27563'),
#   Text(1.0929382902755824, -0.12444233061738566, '2457'),
#   Text(1.0639467711954755, 0.27931571395595095, '2177'),
#   Text(0.9170406447096834, 0.607483708382742, '1934'),
#   Text(0.7291516118116398, 0.8236127287703171, '1335'),
#   Text(0.5472714116508045, 0.9541980936837675, '1218'),
#   Text(0.38367902444264496, 1.0309172644799098, '841'),
#   Text(0.2430046031995519, 1.0728228012229366, '831'),
#   Text(0.1277151337608069, 1.0925606823460468, '501'),
#   Text(0.04198419166706376, 1.099198493289571, '478')],
#  [Text(-0.48460618401289135, -0.3537751353847013, '70.1%'),
#   Text(0.5961481583321359, -0.06787763488221035, '6.2%'),
#   Text(0.5803346024702594, 0.15235402579415505, '5.5%'),
#   Text(0.5002039880234636, 0.3313547500269502, '4.9%'),
#   Text(0.3977190609881671, 0.4492433066019911, '3.4%'),
#   Text(0.29851167908225695, 0.5204716874638731, '3.1%'),
# ...

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='lead_time',y='adr',data=df)
# Out:
# <Axes: xlabel='lead_time', ylabel='adr'>

# %%
plt.figure(figsize=(14,8))
sns.barplot(x='arrival_date_month',y='adr',data=df[df['is_canceled']==1].groupby('arrival_date_month')['adr'].sum().reset_index())
# Out:
# <Axes: xlabel='arrival_date_month', ylabel='adr'>
